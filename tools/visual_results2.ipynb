# %%
import numpy as np, matplotlib.pyplot as plt, os

# %%
dir1 = '../results_save/sketching_time/SD_lr[1.0e+00]bl[1.0e-02]S[0]'
support = np.load(os.path.join(dir1, 'support.npy'))
mass = np.load(os.path.join(dir1, 'mass.npy'))
plt.figure(figsize = (5, 5))
plt.scatter(support[-1, :, 0], support[-1, :, 1], s = 5, c = 'r')
plt.axis('off')
plt.show()

# %%
dir1 = '../results_save/sketching_time/SDCA_lr[1.0e+00]al[1.0e+01]bl[1.0e-02]S[0]'
size = 5
support = np.load(os.path.join(dir1, 'support.npy'))[-1]
mass = np.load(os.path.join(dir1, 'mass.npy'))[-1]
size_list = mass * len(mass) * size
plt.figure(figsize = (5, 5))
plt.scatter(support[:, 0], support[:, 1], s = size_list, c = 'r')
plt.axis('off')
plt.show()

# %%
plt.close()

# %%
plt.figure
plt.hist(mass * len(mass), bins = 40)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/lzj/code/DPVI_discrete/tools/visual_results2.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2B10.214.242.126/home/lzj/code/DPVI_discrete/tools/visual_results2.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> plt.clear()
#       <a href='vscode-notebook-cell://ssh-remote%2B10.214.242.126/home/lzj/code/DPVI_discrete/tools/visual_results2.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> plt.hist(mass * len(mass), bins = 40)
#       <a href='vscode-notebook-cell://ssh-remote%2B10.214.242.126/home/lzj/code/DPVI_discrete/tools/visual_results2.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'clear'
